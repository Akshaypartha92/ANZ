# %% [markdown]
# ## Understanding Dataset

# %%
#Importing packages
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import urllib

# %%
#Reading the dataset
df = pd.read_excel('2019-20-australian-government-contract-data.xlsx')
df_19 = pd.read_excel('2019.xlsx')
df_18 = pd.read_csv('2018.csv', encoding= 'unicode_escape')
df_17 = pd.read_csv('2017.csv', encoding= 'unicode_escape')
df_16 = pd.read_csv('2016.csv', encoding= 'unicode_escape')
df_15 = pd.read_excel('2015.xlsx')

# %%
df_19.head()
# Out:
#              Agency Name Parent Contract ID   Contract ID  \
# 0  Department of Defence                NaN     CN3533145
# 1  Department of Defence                NaN     CN3578441
# 2  Department of Defence                NaN     CN3576603
# 3  Department of Defence                NaN     CN3598565
# 4  Department of Defence          CN3390353  CN3390353-A7
#
#   Contract Notice Type Publish Date Amendment Publish Date  \
# 0               Parent   2018-08-15                    NaT
# 1               Parent   2019-03-19                    NaT
# 2               Parent   2019-03-12                    NaT
# 3               Parent   2019-06-11                    NaT
# 4            Amendment   2016-11-29             2018-11-01
#
#   Applicable Publish Date Start Date Amendment Start Date  \
# 0              2018-08-15 2018-08-10                  NaT
# 1              2019-03-19 2019-01-14                  NaT
# 2              2019-03-12 2019-02-04                  NaT
# 3              2019-06-11 2019-07-01                  NaT
# 4              2018-11-01 2010-01-10           2018-08-30
#
#   Applicable Start Date  ... Supplier Postcode Supplier State  \
# 0            2018-08-10  ...              5000             SA
# 1            2019-01-14  ...              3000            VIC
# 2            2019-02-04  ...              5000             SA
# 3            2019-07-01  ...              3004            VIC
# 4            2018-08-30  ...              4000            QLD
#
#   Supplier Country  Supplier ABN Exempt  Supplier ABN  \
# 0        AUSTRALIA                   No  6.213767e+10
# 1        AUSTRALIA                   No  5.000310e+10
# 2        AUSTRALIA                   No  1.505190e+10
# 3        AUSTRALIA                   No  3.100660e+10
# 4        AUSTRALIA                   No  6.400668e+10
#
#                       Contact Name Contact Phone  \
# 0                       LSD - CAFS             0
# 1       JCG - Joint Health Command             0
# 2  MSD - Maritime Systems Division             0
# 3  EIG - Service Delivery Division             0
# 4                         ASD-AMTS             0
#
#                             Branch                        Division  \
# 0                       LSD - CAFS                            CASG
# 1       JCG - Joint Health Command          JOINT CAPABILITY GROUP
# 2  MSD - Maritime Systems Division                            CASG
# 3  EIG - Service Delivery Division  ESTATE AND INFRASTRUCTURE GROU
# 4                         ASD-AMTS                            CASG
#
#   Office Postcode
# 0            3006
# 1            2610
# 2            2601
# 3            2600
# 4            2609
#
# [5 rows x 44 columns]

# %%
df_19.columns
# Out:
# Index(['Agency Name', 'Parent Contract ID', 'Contract ID',
#        'Contract Notice Type', 'Publish Date', 'Amendment Publish Date',
#        'Applicable Publish Date', 'Start Date', 'Amendment Start Date',
#        'Applicable Start Date', 'FY Publish Date', 'FY Start Date', 'End Date',
#        'Value', 'Amendments Value', 'Applicable Value', 'Description',
#        'Agency Ref ID', 'UNSPSC Code', 'UNSPSC Title', 'Procurement Method',
#        'ATM ID', 'SON ID', 'Panel Arrangement',
#        'Confidentiality Contract Flag', 'Confidentiality Contract Reason',
#        'Confidentiality Outputs Flag', 'Confidentiality Outputs Reason',
#        'Consultancy Flag', 'Consultancy Reason', 'Amendment Reason',
#        'Supplier Name', 'Supplier Address', 'Supplier Suburb',
#        'Supplier Postcode', 'Supplier State', 'Supplier Country',
#        'Supplier ABN Exempt', 'Supplier ABN', 'Contact Name', 'Contact Phone',
#        'Branch', 'Division', 'Office Postcode'],
#       dtype='object')

# %%
df_19.rename(columns={'Amendment Publish Date':'Amendment Date'}, inplace=True)

# %%
df_18.head(5)
# Out:
#                 Agency Name Contract Notice Type Parent Contract ID  \
# 0     Department of Defence            Amendment          CN3350299
# 1  National Blood Authority               Parent                NaN
# 2     Department of Defence               Parent                NaN
# 3     Department of Defence            Amendment          CN3350299
# 4     Department of Defence               Parent                NaN
#
#      Contract ID Publish Date Amendment Date  Start Date Amendment Start Date  \
# 0  CN3350299-A16   14/06/2016     19/10/2017   1/11/2009           19/10/2017
# 1      CN3479056   10/01/2018            NaN   1/01/2018                  NaN
# 2      CN3488844    6/03/2018            NaN  21/02/2018                  NaN
# 3  CN3350299-A18   14/06/2016     31/10/2017   1/11/2009           31/10/2017
# 4      CN3483749    8/02/2018            NaN  23/01/2018                  NaN
#
#      End Date  Contract Value  ...  Supplier Postcode     Supplier State  \
# 0   1/07/2026             NaN  ...         20005-1012  Outside Australia
# 1  31/12/2026    3.351400e+09  ...               3047                VIC
# 2  31/12/2029    2.827549e+09  ...               6166                 WA
# 3   1/07/2026             NaN  ...         20005-1012  Outside Australia
# 4  31/12/2022    1.353494e+09  ...               5112                 SA
#
#   Supplier Country Supplier ABN Exempt  Supplier ABN  \
# 0    United States                 Yes           NaN
# 1        AUSTRALIA                  No  4.816073e+10
# 2        Australia                  No  3.961870e+10
# 3    United States                 Yes           NaN
# 4        AUSTRALIA                  No  2.900842e+10
#
#                               Contact Name Contact Phone  \
# 0          JSF - New Air Combat Capability             0
# 1                            Raquel DeCruz           NaN
# 2  CASGMSD.AUSTENDERQUERIES@DEFENCE.GOV.AU             0
# 3          JSF - New Air Combat Capability             0
# 4          MSD - Maritime Systems Division             0
#
#                             Branch Division Office Postcode
# 0        New Air Combat Capability     CASG            2609
# 1                              NaN      NaN            2602
# 2        Maritime Systems Division     CASG            2600
# 3        New Air Combat Capability     CASG            2609
# 4  MSD - Maritime Systems Division     CASG            2601
#
# [5 rows x 39 columns]

# %%
df_18.columns
# Out:
# Index(['Agency Name', 'Contract Notice Type', 'Parent Contract ID',
#        'Contract ID', 'Publish Date', 'Amendment Date', 'Start Date',
#        'Amendment Start Date', 'End Date', 'Contract Value',
#        'Amendments Value', 'Description', 'Amendment Reason', 'Agency Ref ID',
#        'UNSPSC', 'UNSPSC Title', 'Procurement Method', 'ATM ID', 'SON ID',
#        'Panel Arrangement', 'Confidentiality Contract Flag',
#        'Confidentiality Contract Reason', 'Confidentiality Outputs Flag',
#        'Confidentiality Outputs Reason', 'Consultancy Flag',
#        'Consultancy Reason', 'Supplier Name', 'Supplier Address',
#        'Supplier Suburb', 'Supplier Postcode', 'Supplier State',
#        'Supplier Country', 'Supplier ABN Exempt', 'Supplier ABN',
#        'Contact Name', 'Contact Phone', 'Branch', 'Division',
#        'Office Postcode'],
#       dtype='object')

# %%
df_18.rename(columns={'UNSPSC':'UNSPSC Code', 'Contract Value':'Value'}, inplace=True)

# %%
df_19.dtypes
# Out:
# Agency Name                                object
# Parent Contract ID                         object
# Contract ID                                object
# Contract Notice Type                       object
# Publish Date                       datetime64[ns]
# Amendment Date                     datetime64[ns]
# Applicable Publish Date            datetime64[ns]
# Start Date                         datetime64[ns]
# Amendment Start Date               datetime64[ns]
# Applicable Start Date              datetime64[ns]
# FY Publish Date                            object
# FY Start Date                              object
# End Date                           datetime64[ns]
# Value                                     float64
# Amendments Value                          float64
# Applicable Value                          float64
# Description                                object
# Agency Ref ID                              object
# UNSPSC Code                                 int64
# UNSPSC Title                               object
# Procurement Method                         object
# ATM ID                                     object
# SON ID                                     object
# Panel Arrangement                          object
# Confidentiality Contract Flag              object
# Confidentiality Contract Reason            object
# Confidentiality Outputs Flag               object
# Confidentiality Outputs Reason             object
# Consultancy Flag                           object
# Consultancy Reason                         object
# Amendment Reason                           object
# Supplier Name                              object
# Supplier Address                           object
# Supplier Suburb                            object
# Supplier Postcode                          object
# Supplier State                             object
# Supplier Country                           object
# Supplier ABN Exempt                        object
# Supplier ABN                              float64
# Contact Name                               object
# Contact Phone                              object
# Branch                                     object
# Division                                   object
# Office Postcode                            object
# dtype: object

# %%
np.setdiff1d(df_19.columns, df.columns)
# Out:
# array(['Contract Notice Type', 'FY Publish Date', 'FY Start Date'],
#       dtype=object)

# %%
df_19.drop(['FY Publish Date', 'FY Start Date'], axis=1, inplace=True)
df_19['Applicable FY Year'] = pd.Series([2019 for x in range(len(df_19.index))])

# %%
# creating function to create applicable dates
if 'Applicable Publish Date' in df.columns:
    df_18['Applicable Publish Date'] = pd.Series(['NA' for x in range(len(df_18.index))])
    df_18['Applicable Start Date'] = pd.Series(['NA' for x in range(len(df_18.index))])
    df_18['Applicable Value'] = pd.Series(['NA' for x in range(len(df_18.index))])
    for index, row in df_18['Publish Date'].items():
        if pd.isnull(df_18['Amendment Date'][index]):
            df_18['Applicable Publish Date'][index] = row
            df_18['Applicable Start Date'][index] = df_18['Start Date'][index]
            df_18['Applicable Value'][index] = df_18['Value'][index]
        else:
            df_18['Applicable Publish Date'][index] = df_18['Amendment Date'][index]
            df_18['Applicable Start Date'][index] = df_18['Amendment Start Date'][index]
            df_18['Applicable Value'][index] = df_18['Amendments Value'][index]
# Out:
# <ipython-input-181-ce17a3585d26>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_18['Applicable Publish Date'][index] = df_18['Amendment Date'][index]
# <ipython-input-181-ce17a3585d26>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_18['Applicable Start Date'][index] = df_18['Amendment Start Date'][index]
# <ipython-input-181-ce17a3585d26>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_18['Applicable Value'][index] = df_18['Amendments Value'][index]
# <ipython-input-181-ce17a3585d26>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_18['Applicable Publish Date'][index] = row
# <ipython-input-181-ce17a3585d26>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_18['Applicable Start Date'][index] = df_18['Start Date'][index]
# <ipython-input-181-ce17a3585d26>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_18['Applicable Value'][index] = df_18['Value'][index]

# %%
df_18['Applicable FY Year'] = pd.Series([2018 for x in range(len(df_18.index))])

# %%
df_18['Applicable Publish Date'] = df_18['Applicable Publish Date'].astype('datetime64[ns]')
df_18['Applicable Start Date'] = df_18['Applicable Start Date'].astype('datetime64[ns]')
df_18['End Date'] = df_18['End Date'].astype('datetime64[ns]')

# %%
np.setdiff1d(df_19.columns, df.columns)
# Out:
# array(['Contract Notice Type'], dtype=object)

# %%
df_17.head()
# Out:
#                          Agency Name Parent Contract ID Contract ID  \
# 0   Australian Law Reform Commission                NaN   CN3084902
# 1    Australian Bureau of Statistics                NaN   CN3242742
# 2    Australian Bureau of Statistics                NaN   CN3247582
# 3    Australian Bureau of Statistics                NaN   CN3280247
# 4  Office of the Fair Work Ombudsman                NaN   CN3307395
#
#   Publish Date Amendment Date  Start Date    End Date    Value  \
# 0   19/06/2017            NaN  30/08/2016  29/08/2017  18605.0
# 1    9/08/2016            NaN   8/05/2015  30/06/2015  83000.0
# 2    9/08/2016            NaN   1/06/2015  31/05/2016  28000.0
# 3    9/08/2016            NaN  15/06/2015  14/07/2016  25000.0
# 4   28/02/2017            NaN  26/11/2015  26/11/2015  13799.9
#
#                                   Description Agency Ref ID  ...  \
# 0  online legal resources annual subscription           NaN  ...
# 1    Supply and install 80 sit to stand desks   ABS2015.250  ...
# 2  Procurement of ProQuest ABI/INFORM and ANZ   ABS2015.180  ...
# 3   Enterprise Risk Management Software trial   ABS2015.277  ...
# 4                              LEGAL SERVICES    4500095939  ...
#
#    Supplier Postcode     Supplier State Supplier Country Supplier ABN Exempt  \
# 0               2009                NSW        AUSTRALIA                  No
# 1               3043                VIC        AUSTRALIA                  No
# 2         48106-1346  Outside Australia    UNITED STATES                 Yes
# 3               4000                QLD        AUSTRALIA                  No
# 4               3000                VIC        AUSTRALIA                  No
#
#    Supplier ABN          Contact Name Contact Phone   Branch   Division  \
# 0  6.405891e+10           Sabina Wynn     282386366      NaN        NaN
# 1  4.709392e+10            paul stott           NaN      NaN        NaN
# 2           NaN  procurement services           NaN      NaN        NaN
# 3  6.800978e+10  Procurement Services           NaN      NaN        NaN
# 4  1.906415e+10         VIVIAN ZIAKAS           NaN  FINANCE  CORPORATE
#
#   Office Postcode
# 0            2000
# 1            2617
# 2            2617
# 3            2617
# 4            3000
#
# [5 rows x 36 columns]

# %%
df_17.rename(columns={'Amendment Date':'Amendment publish Date', 'Value': 'Applicable Value', 
                      'Start Date':'Applicable Start Date', 'End Date': 'Applicable End Date'}, inplace=True)
df_17['Applicable FY Year'] = pd.Series([2017 for x in range(len(df_17.index))])
df_17['Amendments Value'] = pd.Series(['NA' for x in range(len(df_17.index))])
df_17['Applicable Publish Date'] = pd.Series(['NA' for x in range(len(df_17.index))])
df_17['Start Date'] = pd.Series(['NA' for x in range(len(df_17.index))])
df_17['Value'] = pd.Series(['NA' for x in range(len(df_17.index))])

# %%
df_17['End Date'] = pd.Series(['NA' for x in range(len(df_17.index))])

# %%
df_17.rename(columns={'Amendment publish Date':'Amendment Date'}, inplace=True)

# %%
df_17['Amendment Start Date'] = pd.Series(['NA' for x in range(len(df_17.index))])

# %%
for index, row in df_17['Publish Date'].items():
        if pd.isnull(df_17['Amendment Date'][index]):
            df_17['Applicable Publish Date'][index] = row
        else:
            df_17['Applicable Publish Date'][index] = df_17['Amendment Date'][index]
# Out:
# <ipython-input-190-b73198e061f6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_17['Applicable Publish Date'][index] = row
# <ipython-input-190-b73198e061f6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_17['Applicable Publish Date'][index] = df_17['Amendment Date'][index]

# %%
df_19.drop('Contract Notice Type', axis=1, inplace=True)
df_18.drop('Contract Notice Type', axis=1, inplace=True)

# %%
df_16.head()
# Out:
#                                Agency Name Parent Contract ID Contract ID  \
# 0  Australian Financial Security Authority                NaN    CN922501
# 1  Australian Financial Security Authority                NaN    CN923311
# 2  Australian Financial Security Authority                NaN    CN924601
# 3  Australian Financial Security Authority                NaN    CN924671
# 4  Australian Financial Security Authority                NaN    CN975381
#
#   Publish Date Amendment Date  Start Date    End Date      Value  \
# 0   26/05/2016            NaN   1/06/2012  30/06/2012  111431.80
# 1   26/05/2016            NaN  12/07/2012  25/11/2013   16305.30
# 2   26/05/2016            NaN  21/08/2012  28/09/2012   17600.07
# 3   26/05/2016            NaN  21/08/2012  30/06/2013  104500.00
# 4   26/05/2016            NaN  21/08/2012  31/12/2012   26400.00
#
#                                        Description Agency Ref ID  ...  \
# 0                      Provision of Building Works  001832-22759  ...
# 1        Provision of Software Licence and Support  001818-22744  ...
# 2                        Provision of IT Equipment  001872-22798  ...
# 3  Provision of Personlisation of Mailing services  001877-22802  ...
# 4                        Provision of EDRM system.  001873-22799  ...
#
#     Supplier Suburb Supplier Postcode Supplier Country Supplier ABN Exempt  \
# 0           TOOWONG              4066        AUSTRALIA                  No
# 1           PHILLIP              2606        AUSTRALIA                  No
# 2  Canberra Airport              2609        AUSTRALIA                  No
# 3         Moorebank              1875        AUSTRALIA                  No
# 4      North Sydney              2060        AUSTRALIA                  No
#
#    Supplier ABN Contact Name Contact Phone Branch Division Office Postcode
# 0  6.912609e+10  Procurement   02 62703455    NaN      NaN            2600
# 1  4.008293e+10  Procurement   02 62703455    NaN      NaN            2600
# 2  6.900100e+10  Procurement   02 62703455    NaN      NaN            2600
# 3  9.413793e+10  Procurement           NaN    NaN      NaN            2600
# 4  8.669901e+10  Procurement   02 62703455    NaN      NaN            2600
#
# [5 rows x 35 columns]

# %%
np.setdiff1d(df.columns, df_16.columns)
# Out:
# array(['Amendment Start Date', 'Amendments Value', 'Applicable FY Year',
#        'Applicable Publish Date', 'Applicable Start Date',
#        'Applicable Value', 'Duration Years', 'Supplier State'],
#       dtype=object)

# %%
df_16.rename(columns={'Value': 'Applicable Value', 
                      'Start Date':'Applicable Start Date', 'End Date': 'Applicable End Date'}, inplace=True)
df_16['Applicable FY Year'] = pd.Series([2016 for x in range(len(df_16.index))])
df_16['Amendments Value'] = pd.Series(['NA' for x in range(len(df_16.index))])
df_16['Applicable Publish Date'] = pd.Series(['NA' for x in range(len(df_16.index))])
df_16['Start Date'] = pd.Series(['NA' for x in range(len(df_16.index))])
df_16['Value'] = pd.Series(['NA' for x in range(len(df_16.index))])
df_16['End Date'] = pd.Series(['NA' for x in range(len(df_16.index))])
df_16['Amendment Start Date'] = pd.Series(['NA' for x in range(len(df_16.index))])

# %%
df_16['Supplier State'] = pd.Series(['NA' for x in range(len(df_16.index))])

# %%
for index, row in df_16['Publish Date'].items():
        if pd.isnull(df_16['Amendment Date'][index]):
            df_16['Applicable Publish Date'][index] = row
        else:
            df_16['Applicable Publish Date'][index] = df_16['Amendment Date'][index]
# Out:
# <ipython-input-196-abbd1bd8e4ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_16['Applicable Publish Date'][index] = row
# <ipython-input-196-abbd1bd8e4ab>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_16['Applicable Publish Date'][index] = df_16['Amendment Date'][index]

# %%
np.setdiff1d(df.columns, df_19.columns)
# Out:
# array(['Duration Years'], dtype=object)

# %%
df_19.columns
# Out:
# Index(['Agency Name', 'Parent Contract ID', 'Contract ID', 'Publish Date',
#        'Amendment Date', 'Applicable Publish Date', 'Start Date',
#        'Amendment Start Date', 'Applicable Start Date', 'End Date', 'Value',
#        'Amendments Value', 'Applicable Value', 'Description', 'Agency Ref ID',
#        'UNSPSC Code', 'UNSPSC Title', 'Procurement Method', 'ATM ID', 'SON ID',
#        'Panel Arrangement', 'Confidentiality Contract Flag',
#        'Confidentiality Contract Reason', 'Confidentiality Outputs Flag',
#        'Confidentiality Outputs Reason', 'Consultancy Flag',
#        'Consultancy Reason', 'Amendment Reason', 'Supplier Name',
#        'Supplier Address', 'Supplier Suburb', 'Supplier Postcode',
#        'Supplier State', 'Supplier Country', 'Supplier ABN Exempt',
#        'Supplier ABN', 'Contact Name', 'Contact Phone', 'Branch', 'Division',
#        'Office Postcode', 'Applicable FY Year'],
#       dtype='object')

# %%
df_19['Duration Years'] = pd.Series(['NA' for x in range(len(df_19.index))])

# %%
for index, row in df_19['Applicable Start Date'].items():
    duration = df_19['End Date'][index] - row
    duration_in_s = duration.total_seconds()
    years = divmod(duration_in_s, 31536000)[0]
    df_19['Duration Years'][index] = years
# Out:
# <ipython-input-200-3cd6e487fb93>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_19['Duration Years'][index] = years

# %%
df_19.head()
# Out:
#              Agency Name Parent Contract ID   Contract ID Publish Date  \
# 0  Department of Defence                NaN     CN3533145   2018-08-15
# 1  Department of Defence                NaN     CN3578441   2019-03-19
# 2  Department of Defence                NaN     CN3576603   2019-03-12
# 3  Department of Defence                NaN     CN3598565   2019-06-11
# 4  Department of Defence          CN3390353  CN3390353-A7   2016-11-29
#
#   Amendment Date Applicable Publish Date Start Date Amendment Start Date  \
# 0            NaT              2018-08-15 2018-08-10                  NaT
# 1            NaT              2019-03-19 2019-01-14                  NaT
# 2            NaT              2019-03-12 2019-02-04                  NaT
# 3            NaT              2019-06-11 2019-07-01                  NaT
# 4     2018-11-01              2018-11-01 2010-01-10           2018-08-30
#
#   Applicable Start Date   End Date  ...  Supplier Country  \
# 0            2018-08-10 2027-06-30  ...         AUSTRALIA
# 1            2019-01-14 2025-06-30  ...         AUSTRALIA
# 2            2019-02-04 2028-06-30  ...         AUSTRALIA
# 3            2019-07-01 2024-06-30  ...         AUSTRALIA
# 4            2018-08-30 2022-06-30  ...         AUSTRALIA
#
#    Supplier ABN Exempt  Supplier ABN                     Contact Name  \
# 0                   No  6.213767e+10                       LSD - CAFS
# 1                   No  5.000310e+10       JCG - Joint Health Command
# 2                   No  1.505190e+10  MSD - Maritime Systems Division
# 3                   No  3.100660e+10  EIG - Service Delivery Division
# 4                   No  6.400668e+10                         ASD-AMTS
#
#   Contact Phone                           Branch  \
# 0             0                       LSD - CAFS
# 1             0       JCG - Joint Health Command
# 2             0  MSD - Maritime Systems Division
# 3             0  EIG - Service Delivery Division
# 4             0                         ASD-AMTS
#
#                          Division Office Postcode Applicable FY Year  \
# 0                            CASG            3006               2019
# 1          JOINT CAPABILITY GROUP            2610               2019
# 2                            CASG            2601               2019
# 3  ESTATE AND INFRASTRUCTURE GROU            2600               2019
# 4                            CASG            2609               2019
#
#   Duration Years
# 0              8
# 1              6
# 2              9
# 3              5
# 4              3
#
# [5 rows x 43 columns]

# %%
df_18['Duration Years'] = pd.Series(['NA' for x in range(len(df_18.index))])
for index, row in df_18['Applicable Start Date'].items():
    duration = df_18['End Date'][index] - row
    duration_in_s = duration.total_seconds()
    years = divmod(duration_in_s, 31536000)[0]
    df_18['Duration Years'][index] = years
# Out:
# <ipython-input-202-f9c46ef24eb8>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_18['Duration Years'][index] = years

# %%
df_17.dtypes
# Out:
# Agency Name                         object
# Parent Contract ID                  object
# Contract ID                         object
# Publish Date                        object
# Amendment Date                      object
# Applicable Start Date               object
# Applicable End Date                 object
# Applicable Value                   float64
# Description                         object
# Agency Ref ID                       object
# UNSPSC Code                          int64
# UNSPSC Title                        object
# Procurement Method                  object
# ATM ID                              object
# SON ID                              object
# Panel Arrangement                   object
# Confidentiality Contract Flag       object
# Confidentiality Contract Reason     object
# Confidentiality Outputs Flag        object
# Confidentiality Outputs Reason      object
# Consultancy Flag                    object
# Consultancy Reason                  object
# Amendment Reason                    object
# Supplier Name                       object
# Supplier Address                    object
# Supplier Suburb                     object
# Supplier Postcode                   object
# Supplier State                      object
# Supplier Country                    object
# Supplier ABN Exempt                 object
# Supplier ABN                       float64
# Contact Name                        object
# Contact Phone                       object
# Branch                              object
# Division                            object
# Office Postcode                     object
# Applicable FY Year                   int64
# Amendments Value                    object
# Applicable Publish Date             object
# Start Date                          object
# Value                               object
# End Date                            object
# Amendment Start Date                object
# dtype: object

# %%
df_17['Applicable End Date'] = pd.to_datetime(df_17['Applicable End Date'], errors= 'coerce')
df_17['Applicable Start Date'] = pd.to_datetime(df_17['Applicable Start Date'], errors = 'coerce')

# %%
df_17['Duration Years'] = pd.Series(['NA' for x in range(len(df_17.index))])
for index, row in df_17['Applicable Start Date'].items():
    duration = df_17['Applicable End Date'][index] - row
    duration_in_s = duration.total_seconds()
    years = divmod(duration_in_s, 31536000)[0]
    df_17['Duration Years'][index] = years
# Out:
# <ipython-input-205-c8bdfda5a254>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_17['Duration Years'][index] = years

# %%
df_16.dtypes
# Out:
# Agency Name                         object
# Parent Contract ID                  object
# Contract ID                         object
# Publish Date                        object
# Amendment Date                      object
# Applicable Start Date               object
# Applicable End Date                 object
# Applicable Value                   float64
# Description                         object
# Agency Ref ID                       object
# UNSPSC Code                          int64
# UNSPSC Title                        object
# Procurement Method                  object
# ATM ID                              object
# SON ID                              object
# Panel Arrangement                   object
# Confidentiality Contract Flag       object
# Confidentiality Contract Reason     object
# Confidentiality Outputs Flag        object
# Confidentiality Outputs Reason      object
# Consultancy Flag                    object
# Consultancy Reason                  object
# Amendment Reason                    object
# Supplier Name                       object
# Supplier Address                    object
# Supplier Suburb                     object
# Supplier Postcode                   object
# Supplier Country                    object
# Supplier ABN Exempt                 object
# Supplier ABN                       float64
# Contact Name                        object
# Contact Phone                       object
# Branch                              object
# Division                            object
# Office Postcode                     object
# Applicable FY Year                   int64
# Amendments Value                    object
# Applicable Publish Date             object
# Start Date                          object
# Value                               object
# End Date                            object
# Amendment Start Date                object
# Supplier State                      object
# dtype: object

# %%
df_16['Applicable End Date'] = pd.to_datetime(df_16['Applicable End Date'], errors= 'coerce')
df_16['Applicable Start Date'] = pd.to_datetime(df_16['Applicable Start Date'], errors = 'coerce')

# %%
df_16['Duration Years'] = pd.Series(['NA' for x in range(len(df_16.index))])
for index, row in df_16['Applicable Start Date'].items():
    duration = df_16['Applicable End Date'][index] - row
    duration_in_s = duration.total_seconds()
    years = divmod(duration_in_s, 31536000)[0]
    df_16['Duration Years'][index] = years
# Out:
# <ipython-input-208-b19170bc16a6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_16['Duration Years'][index] = years

# %%
df['Applicable FY Year'].value_counts()
# Out:
# 2020    81174
# Name: Applicable FY Year, dtype: int64

# %%
df_19['Applicable FY Year'].value_counts()
# Out:
# 2019    78150
# Name: Applicable FY Year, dtype: int64

# %%
df_18['Applicable FY Year'].value_counts()
# Out:
# 2018    73458
# Name: Applicable FY Year, dtype: int64

# %%
df_17['Applicable FY Year'].value_counts()
# Out:
# 2017    64092
# Name: Applicable FY Year, dtype: int64

# %%
df_16['Applicable FY Year'].value_counts()
# Out:
# 2016    70338
# Name: Applicable FY Year, dtype: int64

# %%
df.dtypes
# Out:
# Agency Name                                object
# Parent Contract ID                         object
# Contract ID                                object
# Publish Date                       datetime64[ns]
# Start Date                         datetime64[ns]
# End Date                           datetime64[ns]
# Value                                     float64
# Amendment Date                     datetime64[ns]
# Amendment Start Date               datetime64[ns]
# Amendments Value                          float64
# Description                                object
# Agency Ref ID                              object
# UNSPSC Code                                 int64
# UNSPSC Title                               object
# Procurement Method                         object
# ATM ID                                     object
# SON ID                                     object
# Panel Arrangement                          object
# Confidentiality Contract Flag              object
# Confidentiality Contract Reason            object
# Confidentiality Outputs Flag               object
# Confidentiality Outputs Reason             object
# Consultancy Flag                           object
# Consultancy Reason                         object
# Amendment Reason                           object
# Supplier Name                              object
# Supplier Address                           object
# Supplier Suburb                            object
# Supplier Postcode                          object
# Supplier State                             object
# Supplier Country                           object
# Supplier ABN Exempt                        object
# Supplier ABN                              float64
# Contact Name                               object
# Contact Phone                              object
# Branch                                     object
# Division                                   object
# Office Postcode                            object
# Applicable Publish Date            datetime64[ns]
# Applicable FY Year                          int64
# Applicable Value                          float64
# Duration Years                            float64
# Applicable Start Date              datetime64[ns]
# dtype: object

# %%
df_19.dtypes
# Out:
# Agency Name                                object
# Parent Contract ID                         object
# Contract ID                                object
# Publish Date                       datetime64[ns]
# Amendment Date                     datetime64[ns]
# Applicable Publish Date            datetime64[ns]
# Start Date                         datetime64[ns]
# Amendment Start Date               datetime64[ns]
# Applicable Start Date              datetime64[ns]
# End Date                           datetime64[ns]
# Value                                     float64
# Amendments Value                          float64
# Applicable Value                          float64
# Description                                object
# Agency Ref ID                              object
# UNSPSC Code                                 int64
# UNSPSC Title                               object
# Procurement Method                         object
# ATM ID                                     object
# SON ID                                     object
# Panel Arrangement                          object
# Confidentiality Contract Flag              object
# Confidentiality Contract Reason            object
# Confidentiality Outputs Flag               object
# Confidentiality Outputs Reason             object
# Consultancy Flag                           object
# Consultancy Reason                         object
# Amendment Reason                           object
# Supplier Name                              object
# Supplier Address                           object
# Supplier Suburb                            object
# Supplier Postcode                          object
# Supplier State                             object
# Supplier Country                           object
# Supplier ABN Exempt                        object
# Supplier ABN                              float64
# Contact Name                               object
# Contact Phone                              object
# Branch                                     object
# Division                                   object
# Office Postcode                            object
# Applicable FY Year                          int64
# Duration Years                             object
# dtype: object

# %%
df_18.dtypes
# Out:
# Agency Name                                object
# Parent Contract ID                         object
# Contract ID                                object
# Publish Date                               object
# Amendment Date                             object
# Start Date                                 object
# Amendment Start Date                       object
# End Date                           datetime64[ns]
# Value                                     float64
# Amendments Value                          float64
# Description                                object
# Amendment Reason                           object
# Agency Ref ID                              object
# UNSPSC Code                                 int64
# UNSPSC Title                               object
# Procurement Method                         object
# ATM ID                                     object
# SON ID                                     object
# Panel Arrangement                          object
# Confidentiality Contract Flag              object
# Confidentiality Contract Reason            object
# Confidentiality Outputs Flag               object
# Confidentiality Outputs Reason             object
# Consultancy Flag                           object
# Consultancy Reason                         object
# Supplier Name                              object
# Supplier Address                           object
# Supplier Suburb                            object
# Supplier Postcode                          object
# Supplier State                             object
# Supplier Country                           object
# Supplier ABN Exempt                        object
# Supplier ABN                              float64
# Contact Name                               object
# Contact Phone                              object
# Branch                                     object
# Division                                   object
# Office Postcode                            object
# Applicable Publish Date            datetime64[ns]
# Applicable Start Date              datetime64[ns]
# Applicable Value                           object
# Applicable FY Year                          int64
# Duration Years                             object
# dtype: object

# %%
df_17.dtypes
# Out:
# Agency Name                                object
# Parent Contract ID                         object
# Contract ID                                object
# Publish Date                               object
# Amendment Date                             object
# Applicable Start Date              datetime64[ns]
# Applicable End Date                datetime64[ns]
# Applicable Value                          float64
# Description                                object
# Agency Ref ID                              object
# UNSPSC Code                                 int64
# UNSPSC Title                               object
# Procurement Method                         object
# ATM ID                                     object
# SON ID                                     object
# Panel Arrangement                          object
# Confidentiality Contract Flag              object
# Confidentiality Contract Reason            object
# Confidentiality Outputs Flag               object
# Confidentiality Outputs Reason             object
# Consultancy Flag                           object
# Consultancy Reason                         object
# Amendment Reason                           object
# Supplier Name                              object
# Supplier Address                           object
# Supplier Suburb                            object
# Supplier Postcode                          object
# Supplier State                             object
# Supplier Country                           object
# Supplier ABN Exempt                        object
# Supplier ABN                              float64
# Contact Name                               object
# Contact Phone                              object
# Branch                                     object
# Division                                   object
# Office Postcode                            object
# Applicable FY Year                          int64
# Amendments Value                           object
# Applicable Publish Date                    object
# Start Date                                 object
# Value                                      object
# End Date                                   object
# Amendment Start Date                       object
# Duration Years                             object
# dtype: object

# %%
df_16.dtypes
# Out:
# Agency Name                                object
# Parent Contract ID                         object
# Contract ID                                object
# Publish Date                               object
# Amendment Date                             object
# Applicable Start Date              datetime64[ns]
# Applicable End Date                datetime64[ns]
# Applicable Value                          float64
# Description                                object
# Agency Ref ID                              object
# UNSPSC Code                                 int64
# UNSPSC Title                               object
# Procurement Method                         object
# ATM ID                                     object
# SON ID                                     object
# Panel Arrangement                          object
# Confidentiality Contract Flag              object
# Confidentiality Contract Reason            object
# Confidentiality Outputs Flag               object
# Confidentiality Outputs Reason             object
# Consultancy Flag                           object
# Consultancy Reason                         object
# Amendment Reason                           object
# Supplier Name                              object
# Supplier Address                           object
# Supplier Suburb                            object
# Supplier Postcode                          object
# Supplier Country                           object
# Supplier ABN Exempt                        object
# Supplier ABN                              float64
# Contact Name                               object
# Contact Phone                              object
# Branch                                     object
# Division                                   object
# Office Postcode                            object
# Applicable FY Year                          int64
# Amendments Value                           object
# Applicable Publish Date                    object
# Start Date                                 object
# Value                                      object
# End Date                                   object
# Amendment Start Date                       object
# Supplier State                             object
# Duration Years                             object
# dtype: object

# %%
list_of_col = ['Agency Name', 'Parent Contract ID', 'Contract ID', 'Publish Date',
       'Start Date', 'End Date', 'Value', 'Amendment Date',
       'Amendment Start Date', 'Amendments Value', 'Description',
       'Agency Ref ID', 'UNSPSC Code', 'UNSPSC Title', 'Procurement Method',
       'ATM ID', 'SON ID', 'Panel Arrangement',
       'Confidentiality Contract Flag', 'Confidentiality Contract Reason',
       'Confidentiality Outputs Flag', 'Confidentiality Outputs Reason',
       'Consultancy Flag', 'Consultancy Reason', 'Amendment Reason',
       'Supplier Name', 'Supplier Address', 'Supplier Suburb',
       'Supplier Postcode', 'Supplier State', 'Supplier Country',
       'Supplier ABN Exempt', 'Supplier ABN', 'Contact Name', 'Contact Phone',
       'Branch', 'Division', 'Office Postcode', 'Applicable Publish Date',
       'Applicable FY Year', 'Applicable Value', 'Duration Years',
       'Applicable Start Date']

# %%
df_19 = df_19[list_of_col]
df_18 = df_18[list_of_col]
df_17 = df_17[list_of_col]
df_16 = df_16[list_of_col]

# %%
df.head(10)
# Out:
#                        Agency Name Parent Contract ID   Contract ID  \
# 0            Department of Defence                NaN     CN3620990
# 1  Australian Bureau of Statistics          CN3602517  CN3602517-A1
# 2               Services Australia                NaN     CN3671573
# 3             Department of Health                NaN     CN3648860
# 4  Administrative Appeals Tribunal          CN3591066  CN3591066-A1
# 5  Administrative Appeals Tribunal                NaN     CN3606106
# 6  Administrative Appeals Tribunal                NaN     CN3661660
# 7  Administrative Appeals Tribunal                NaN     CN3669641
# 8  Administrative Appeals Tribunal                NaN     CN3654907
# 9  Administrative Appeals Tribunal                NaN     CN3688783
#
#   Publish Date Start Date   End Date       Value Amendment Date  \
# 0   2019-08-20 2019-05-01 2019-05-31    16163.40            NaT
# 1   2019-06-21 2018-07-01 2023-06-30  1964000.00     2020-05-25
# 2   2020-04-07 2020-03-19 2020-03-27   155997.60            NaT
# 3   2019-12-19 2020-01-02 2020-06-30   169542.12            NaT
# 4   2019-05-13 2019-02-27 2019-07-31    13263.55     2019-07-25
# 5   2019-07-01 2019-06-28 2020-06-30    78944.80            NaT
# 6   2020-02-24 2020-02-11 2021-12-31    54214.11            NaT
# 7   2020-03-31 2020-03-19 2021-03-18    52546.74            NaT
# 8   2020-01-23 2019-07-01 2020-06-30    44075.00            NaT
# 9   2020-06-11 2020-05-26 2023-06-27   158927.14            NaT
#
#   Amendment Start Date  Amendments Value  ...           Contact Name  \
# 0                  NaT               NaN  ...    Army Forces Command
# 1           2020-05-25         648000.00  ...  Director, procurement
# 2                  NaT               NaN  ...    PURCHASING HELPDESK
# 3                  NaT               NaN  ...                    BMU
# 4           2019-06-01          13263.55  ...    PROCUREMENT OFFICER
# 5                  NaT               NaN  ...    PROCUREMENT OFFICER
# 6                  NaT               NaN  ...    PROCUREMENT OFFICER
# 7                  NaT               NaN  ...    PROCUREMENT OFFICER
# 8                  NaT               NaN  ...    Procurement Officer
# 9                  NaT               NaN  ...    PROCUREMENT OFFICER
#
#    Contact Phone                                             Branch  \
# 0              0                                Army Forces Command
# 1            NaN                                                NaN
# 2   1800 906 144                                         DHS Branch
# 3   02 6289 4977                                                NaN
# 4  (03)9454 6100  Administrative Appeals Tribunal Administrative...
# 5  (03)9454 6100  Administrative Appeals Tribunal Administrative...
# 6  (03)9454 6100  Administrative Appeals Tribunal Administrative...
# 7  (03)9454 6100  Administrative Appeals Tribunal Administrative...
# 8            NaN                                                NaN
# 9  (03)9454 6100  Administrative Appeals Tribunal Administrative...
#
#                                  Division Office Postcode  \
# 0                       ARMY HEADQUARTERS            2021
# 1                                     NaN            2617
# 2                            DHS Division            2900
# 3  Cancer Hearing and Program Support DIV            2606
# 4     AAT Administrative Appeals Tribunal            4000
# 5     AAT Administrative Appeals Tribunal            4000
# 6     AAT Administrative Appeals Tribunal            4000
# 7     AAT Administrative Appeals Tribunal            4000
# 8                                     NaN            3000
# 9     AAT Administrative Appeals Tribunal            4000
#
#   Applicable Publish Date Applicable FY Year Applicable Value Duration Years  \
# 0              2019-08-20               2020         16163.40       0.222222
# 1              2020-05-25               2020        648000.00       3.097222
# 2              2020-04-07               2020        155997.60       0.027778
# 3              2019-12-19               2020        169542.12       0.530556
# 4              2019-07-25               2020         13263.55       0.016667
# 5              2019-07-01               2020         78944.80       0.997222
# 6              2020-02-24               2020         54214.11       1.852778
# 7              2020-03-31               2020         52546.74       0.966667
# 8              2020-01-23               2020         44075.00       0.436111
# 9              2020-06-11               2020        158927.14       3.044444
#
#   Applicable Start Date
# 0            2019-05-01
# 1            2020-05-25
# 2            2020-03-19
# 3            2020-01-02
# 4            2019-06-01
# 5            2019-06-28
# 6            2020-02-11
# 7            2020-03-19
# 8            2019-07-01
# 9            2020-05-26
#
# [10 rows x 43 columns]

# %%
np.setdiff1d(df.columns, df_16.columns)
# Out:
# array([], dtype=object)

# %%
bigdata = df.append(df_19, ignore_index=True)

# %%
bigdata1 = bigdata.append(df_18, ignore_index=True)

# %%
bigdata2 = bigdata1.append(df_17, ignore_index=True)

# %%
bigdata3 = bigdata2.append(df_16, ignore_index=True)

# %%
# Creating CSV file with the clean data
bigdata.to_csv('combination.csv', encoding='utf-8', index=False)

# %%
bigdata3['Applicable FY Year'].value_counts()
# Out:
# 2020    81174
# 2019    78150
# 2018    73458
# 2016    70338
# 2017    64092
# Name: Applicable FY Year, dtype: int64

# %%
bigdata3.head()
# Out:
#                        Agency Name Parent Contract ID   Contract ID  \
# 0            Department of Defence                NaN     CN3620990
# 1  Australian Bureau of Statistics          CN3602517  CN3602517-A1
# 2               Services Australia                NaN     CN3671573
# 3             Department of Health                NaN     CN3648860
# 4  Administrative Appeals Tribunal          CN3591066  CN3591066-A1
#
#           Publish Date           Start Date             End Date      Value  \
# 0  2019-08-20 00:00:00  2019-05-01 00:00:00  2019-05-31 00:00:00    16163.4
# 1  2019-06-21 00:00:00  2018-07-01 00:00:00  2023-06-30 00:00:00  1.964e+06
# 2  2020-04-07 00:00:00  2020-03-19 00:00:00  2020-03-27 00:00:00     155998
# 3  2019-12-19 00:00:00  2020-01-02 00:00:00  2020-06-30 00:00:00     169542
# 4  2019-05-13 00:00:00  2019-02-27 00:00:00  2019-07-31 00:00:00    13263.5
#
#         Amendment Date Amendment Start Date Amendments Value  ...  \
# 0                  NaT                  NaT              NaN  ...
# 1  2020-05-25 00:00:00  2020-05-25 00:00:00           648000  ...
# 2                  NaT                  NaT              NaN  ...
# 3                  NaT                  NaT              NaN  ...
# 4  2019-07-25 00:00:00  2019-06-01 00:00:00          13263.5  ...
#
#             Contact Name  Contact Phone  \
# 0    Army Forces Command              0
# 1  Director, procurement            NaN
# 2    PURCHASING HELPDESK   1800 906 144
# 3                    BMU   02 6289 4977
# 4    PROCUREMENT OFFICER  (03)9454 6100
#
#                                               Branch  \
# 0                                Army Forces Command
# 1                                                NaN
# 2                                         DHS Branch
# 3                                                NaN
# 4  Administrative Appeals Tribunal Administrative...
#
#                                  Division Office Postcode  \
# 0                       ARMY HEADQUARTERS            2021
# 1                                     NaN            2617
# 2                            DHS Division            2900
# 3  Cancer Hearing and Program Support DIV            2606
# 4     AAT Administrative Appeals Tribunal            4000
#
#   Applicable Publish Date Applicable FY Year Applicable Value Duration Years  \
# 0     2019-08-20 00:00:00               2020          16163.4       0.222222
# 1     2020-05-25 00:00:00               2020           648000        3.09722
# 2     2020-04-07 00:00:00               2020           155998      0.0277778
# 3     2019-12-19 00:00:00               2020           169542       0.530556
# 4     2019-07-25 00:00:00               2020          13263.5      0.0166667
#
#   Applicable Start Date
# 0            2019-05-01
# 1            2020-05-25
# 2            2020-03-19
# 3            2020-01-02
# 4            2019-06-01
#
# [5 rows x 43 columns]

# %%
bigdata3.isnull().sum()
# Out:
# Agency Name                             0
# Parent Contract ID                 313416
# Contract ID                             0
# Publish Date                            0
# Start Date                              0
# End Date                                0
# Value                               12868
# Amendment Date                     313416
# Amendment Start Date               188957
# Amendments Value                   188764
# Description                             3
# Agency Ref ID                        6752
# UNSPSC Code                             0
# UNSPSC Title                            0
# Procurement Method                      0
# ATM ID                             268727
# SON ID                             234432
# Panel Arrangement                  234842
# Confidentiality Contract Flag        3275
# Confidentiality Contract Reason    359126
# Confidentiality Outputs Flag         3275
# Confidentiality Outputs Reason     359428
# Consultancy Flag                     3275
# Consultancy Reason                 349081
# Amendment Reason                   313416
# Supplier Name                           0
# Supplier Address                   135744
# Supplier Suburb                       315
# Supplier Postcode                    1783
# Supplier State                          0
# Supplier Country                        0
# Supplier ABN Exempt                     0
# Supplier ABN                        18362
# Contact Name                            0
# Contact Phone                      111968
# Branch                             111808
# Division                            57155
# Office Postcode                         0
# Applicable Publish Date                 0
# Applicable FY Year                      0
# Applicable Value                        0
# Duration Years                        117
# Applicable Start Date                 114
# dtype: int64

# %%
# Combining 4 years of data together

# %%
bigdata3['Applicable Publish Date'][0]
# Out:
# Timestamp('2019-08-20 00:00:00')

# %%
bigdata3.shape
# Out:
# (367212, 43)

# %%
bigdata3.columns
# Out:
# Index(['Agency Name', 'Parent Contract ID', 'Contract ID', 'Publish Date',
#        'Start Date', 'End Date', 'Value', 'Amendment Date',
#        'Amendment Start Date', 'Amendments Value', 'Description',
#        'Agency Ref ID', 'UNSPSC Code', 'UNSPSC Title', 'Procurement Method',
#        'ATM ID', 'SON ID', 'Panel Arrangement',
#        'Confidentiality Contract Flag', 'Confidentiality Contract Reason',
#        'Confidentiality Outputs Flag', 'Confidentiality Outputs Reason',
#        'Consultancy Flag', 'Consultancy Reason', 'Amendment Reason',
#        'Supplier Name', 'Supplier Address', 'Supplier Suburb',
#        'Supplier Postcode', 'Supplier State', 'Supplier Country',
#        'Supplier ABN Exempt', 'Supplier ABN', 'Contact Name', 'Contact Phone',
#        'Branch', 'Division', 'Office Postcode', 'Applicable Publish Date',
#        'Applicable FY Year', 'Applicable Value', 'Duration Years',
#        'Applicable Start Date'],
#       dtype='object')

# %% [markdown]
# #### Dropping ID fields as they aren't contributing to the data exploration steps

# %%
ID_cols = ['Parent Contract ID', 'Contract ID', 'Agency Ref ID', 'ATM ID', 'SON ID']

# %%
#creating a copy of the data before dropping columns

df_IDs_dropped = bigdata3.copy()

# %%
for col in df_IDs_dropped.columns:
    if 'ID' in col:
        df_IDs_dropped.drop(col, axis=1, inplace=True)

# %%
df_IDs_dropped.isnull().sum()
# Out:
# Agency Name                             0
# Publish Date                            0
# Start Date                              0
# End Date                                0
# Value                               12868
# Amendment Date                     313416
# Amendment Start Date               188957
# Amendments Value                   188764
# Description                             3
# UNSPSC Code                             0
# UNSPSC Title                            0
# Procurement Method                      0
# Panel Arrangement                  234842
# Confidentiality Contract Flag        3275
# Confidentiality Contract Reason    359126
# Confidentiality Outputs Flag         3275
# Confidentiality Outputs Reason     359428
# Consultancy Flag                     3275
# Consultancy Reason                 349081
# Amendment Reason                   313416
# Supplier Name                           0
# Supplier Address                   135744
# Supplier Suburb                       315
# Supplier Postcode                    1783
# Supplier State                          0
# Supplier Country                        0
# Supplier ABN Exempt                     0
# Supplier ABN                        18362
# Contact Name                            0
# Contact Phone                      111968
# Branch                             111808
# Division                            57155
# Office Postcode                         0
# Applicable Publish Date                 0
# Applicable FY Year                      0
# Applicable Value                        0
# Duration Years                        117
# Applicable Start Date                 114
# dtype: int64

# %% [markdown]
# #### Applicable Date is created by taking account of publish date & amendment dates so it's convenient to assume that **applicable publish date is the acutal publish date** & **applicable start date is actual start date**, which can be cross referenced from the duration years.

# %%
# Dropping Amendment columns as they are considered by the applicable columns & can be considered as data leakage
amend_col = ['Publish Date','Start Date','Value','Amendment Date','Amendment Start Date', 'Amendments Value']

# %%
for col in df_IDs_dropped.columns:
    if col in amend_col:
        df_IDs_dropped.drop(col, axis=1, inplace=True)

# %%
df_IDs_dropped.isnull().sum()
# Out:
# Agency Name                             0
# End Date                                0
# Description                             3
# UNSPSC Code                             0
# UNSPSC Title                            0
# Procurement Method                      0
# Panel Arrangement                  234842
# Confidentiality Contract Flag        3275
# Confidentiality Contract Reason    359126
# Confidentiality Outputs Flag         3275
# Confidentiality Outputs Reason     359428
# Consultancy Flag                     3275
# Consultancy Reason                 349081
# Amendment Reason                   313416
# Supplier Name                           0
# Supplier Address                   135744
# Supplier Suburb                       315
# Supplier Postcode                    1783
# Supplier State                          0
# Supplier Country                        0
# Supplier ABN Exempt                     0
# Supplier ABN                        18362
# Contact Name                            0
# Contact Phone                      111968
# Branch                             111808
# Division                            57155
# Office Postcode                         0
# Applicable Publish Date                 0
# Applicable FY Year                      0
# Applicable Value                        0
# Duration Years                        117
# Applicable Start Date                 114
# dtype: int64

# %%
# Changing End Date to applicable End date
df_IDs_dropped.rename(columns={'End Date':'Applicable End Date'}, inplace=True)

# %%
df_IDs_dropped.isnull().sum()
# Out:
# Agency Name                             0
# Applicable End Date                     0
# Description                             3
# UNSPSC Code                             0
# UNSPSC Title                            0
# Procurement Method                      0
# Panel Arrangement                  234842
# Confidentiality Contract Flag        3275
# Confidentiality Contract Reason    359126
# Confidentiality Outputs Flag         3275
# Confidentiality Outputs Reason     359428
# Consultancy Flag                     3275
# Consultancy Reason                 349081
# Amendment Reason                   313416
# Supplier Name                           0
# Supplier Address                   135744
# Supplier Suburb                       315
# Supplier Postcode                    1783
# Supplier State                          0
# Supplier Country                        0
# Supplier ABN Exempt                     0
# Supplier ABN                        18362
# Contact Name                            0
# Contact Phone                      111968
# Branch                             111808
# Division                            57155
# Office Postcode                         0
# Applicable Publish Date                 0
# Applicable FY Year                      0
# Applicable Value                        0
# Duration Years                        117
# Applicable Start Date                 114
# dtype: int64

# %%
cols = list(df_IDs_dropped.columns.values)

# %%
cols
# Out:
# ['Agency Name',
#  'Applicable End Date',
#  'Description',
#  'UNSPSC Code',
#  'UNSPSC Title',
#  'Procurement Method',
#  'Panel Arrangement',
#  'Confidentiality Contract Flag',
#  'Confidentiality Contract Reason',
#  'Confidentiality Outputs Flag',
#  'Confidentiality Outputs Reason',
#  'Consultancy Flag',
#  'Consultancy Reason',
#  'Amendment Reason',
#  'Supplier Name',
#  'Supplier Address',
#  'Supplier Suburb',
#  'Supplier Postcode',
#  'Supplier State',
#  'Supplier Country',
#  'Supplier ABN Exempt',
#  'Supplier ABN',
#  'Contact Name',
#  'Contact Phone',
#  'Branch',
#  'Division',
#  'Office Postcode',
#  'Applicable Publish Date',
#  'Applicable FY Year',
#  'Applicable Value',
#  'Duration Years',
#  'Applicable Start Date']

# %%
reordered_cols = ['Agency Name',
 'Applicable Publish Date',
 'Applicable Start Date',
 'Applicable End Date',
 'Applicable Value',
 'Applicable FY Year',
 'Duration Years',
 'Amendment Reason',
 'Description',
 'UNSPSC Code',
 'UNSPSC Title',
 'Procurement Method',
 'Panel Arrangement',
 'Confidentiality Contract Flag',
 'Confidentiality Contract Reason',
 'Confidentiality Outputs Flag',
 'Confidentiality Outputs Reason',
 'Consultancy Flag',
 'Consultancy Reason',
 'Supplier Name',
 'Supplier Address',
 'Supplier Suburb',
 'Supplier Postcode',
 'Supplier State',
 'Supplier Country',
 'Supplier ABN Exempt',
 'Supplier ABN',
 'Contact Name',
 'Contact Phone',
 'Branch',
 'Division',
 'Office Postcode']

# %%
df_IDs_dropped = df_IDs_dropped[reordered_cols]

# %%
df_IDs_dropped.isnull().sum()
# Out:
# Agency Name                             0
# Applicable Publish Date                 0
# Applicable Start Date                 114
# Applicable End Date                     0
# Applicable Value                        0
# Applicable FY Year                      0
# Duration Years                        117
# Amendment Reason                   313416
# Description                             3
# UNSPSC Code                             0
# UNSPSC Title                            0
# Procurement Method                      0
# Panel Arrangement                  234842
# Confidentiality Contract Flag        3275
# Confidentiality Contract Reason    359126
# Confidentiality Outputs Flag         3275
# Confidentiality Outputs Reason     359428
# Consultancy Flag                     3275
# Consultancy Reason                 349081
# Supplier Name                           0
# Supplier Address                   135744
# Supplier Suburb                       315
# Supplier Postcode                    1783
# Supplier State                          0
# Supplier Country                        0
# Supplier ABN Exempt                     0
# Supplier ABN                        18362
# Contact Name                            0
# Contact Phone                      111968
# Branch                             111808
# Division                            57155
# Office Postcode                         0
# dtype: int64

# %% [markdown]
# #### Amendment information is not lost as if there is any amendment than reason is mentioned in the "Amendemnt reason" column.

# %%
# Storing Contact names & details of supplier in seperate data frame for future use but they don't contribute into the data analysis.
df_supplier_details = df_IDs_dropped[['Supplier Name', 'Contact Name', 'Contact Phone', 'Supplier ABN', 'Supplier Address', 'Supplier Suburb', 'Supplier Postcode', 'Supplier State', 'Supplier Country', 'Branch', 'Division','Office Postcode']]
df_IDs_dropped.drop(['Contact Name', 'Contact Phone', 'Supplier ABN'], axis=1, inplace=True)

# %%
df_supplier_details.head()
# Out:
#                      Supplier Name           Contact Name  Contact Phone  \
# 0  BLP TRAINING & SERVICES PTY LTD    Army Forces Command              0
# 1            IBM Australia Limited  Director, procurement            NaN
# 2           Benestar Group Pty Ltd    PURCHASING HELPDESK   1800 906 144
# 3         PEOPLEBANK AUSTRALIA LTD                    BMU   02 6289 4977
# 4       LAUNCH RECRUITMENT PTY LTD    PROCUREMENT OFFICER  (03)9454 6100
#
#    Supplier ABN               Supplier Address         Supplier Suburb  \
# 0  4.007962e+10                            NaN               BEENLEIGH
# 1  7.900002e+10                            NaN           Pennant Hills
# 2  6.100354e+10                   PO Box Q1436  QVB Post Office Sydney
# 3  4.200400e+10                            NaN            NORTH SYDNEY
# 4  5.411914e+10  LEVEL 10 1 CASTLEREAGH STREET                  SYDNEY
#
#   Supplier Postcode Supplier State Supplier Country  \
# 0              4207            QLD        AUSTRALIA
# 1              1715            NSW        AUSTRALIA
# 2              1230            NSW        Australia
# 3              2060            NSW        Australia
# 4              2000            NSW        AUSTRALIA
#
#                                               Branch  \
# 0                                Army Forces Command
# 1                                                NaN
# 2                                         DHS Branch
# 3                                                NaN
# 4  Administrative Appeals Tribunal Administrative...
#
#                                  Division Office Postcode
# 0                       ARMY HEADQUARTERS            2021
# 1                                     NaN            2617
# 2                            DHS Division            2900
# 3  Cancer Hearing and Program Support DIV            2606
# 4     AAT Administrative Appeals Tribunal            4000

# %%
df_IDs_dropped.head()
# Out:
#                        Agency Name Applicable Publish Date  \
# 0            Department of Defence     2019-08-20 00:00:00
# 1  Australian Bureau of Statistics     2020-05-25 00:00:00
# 2               Services Australia     2020-04-07 00:00:00
# 3             Department of Health     2019-12-19 00:00:00
# 4  Administrative Appeals Tribunal     2019-07-25 00:00:00
#
#   Applicable Start Date  Applicable End Date Applicable Value  \
# 0            2019-05-01  2019-05-31 00:00:00          16163.4
# 1            2020-05-25  2023-06-30 00:00:00           648000
# 2            2020-03-19  2020-03-27 00:00:00           155998
# 3            2020-01-02  2020-06-30 00:00:00           169542
# 4            2019-06-01  2019-07-31 00:00:00          13263.5
#
#    Applicable FY Year Duration Years Amendment Reason             Description  \
# 0                2020       0.222222              NaN       Fitness Equipment
# 1                2020        3.09722        Variation    Software Maintenance
# 2                2020      0.0277778              NaN       Training Services
# 3                2020       0.530556              NaN             Labour Hire
# 4                2020      0.0166667   Extension date  Labour hire contractor
#
#    UNSPSC Code  ...                    Supplier Name  \
# 0     49200000  ...  BLP TRAINING & SERVICES PTY LTD
# 1     81112200  ...            IBM Australia Limited
# 2     86000000  ...           Benestar Group Pty Ltd
# 3     80111700  ...         PEOPLEBANK AUSTRALIA LTD
# 4     80111600  ...       LAUNCH RECRUITMENT PTY LTD
#
#                 Supplier Address         Supplier Suburb Supplier Postcode  \
# 0                            NaN               BEENLEIGH              4207
# 1                            NaN           Pennant Hills              1715
# 2                   PO Box Q1436  QVB Post Office Sydney              1230
# 3                            NaN            NORTH SYDNEY              2060
# 4  LEVEL 10 1 CASTLEREAGH STREET                  SYDNEY              2000
#
#   Supplier State Supplier Country Supplier ABN Exempt  \
# 0            QLD        AUSTRALIA                  No
# 1            NSW        AUSTRALIA                  No
# 2            NSW        Australia                  No
# 3            NSW        Australia                  No
# 4            NSW        AUSTRALIA                  No
#
#                                               Branch  \
# 0                                Army Forces Command
# 1                                                NaN
# 2                                         DHS Branch
# 3                                                NaN
# 4  Administrative Appeals Tribunal Administrative...
#
#                                  Division Office Postcode
# 0                       ARMY HEADQUARTERS            2021
# 1                                     NaN            2617
# 2                            DHS Division            2900
# 3  Cancer Hearing and Program Support DIV            2606
# 4     AAT Administrative Appeals Tribunal            4000
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Dropping UNSPSC code & Creating a clean dataframe Also checking for grammatical errors in the levels of features

# %%
clean_df = df_IDs_dropped.drop('UNSPSC Code', axis=1)

# %%
clean_df["Amendment Reason"].fillna("No Amendment done", inplace = True)

# %%
#Converting Countries names to Capital Letters 
clean_df['Supplier Country'] = clean_df['Supplier Country'].str.upper()

# %%
clean_df.head()
# Out:
#                        Agency Name Applicable Publish Date  \
# 0            Department of Defence     2019-08-20 00:00:00
# 1  Australian Bureau of Statistics     2020-05-25 00:00:00
# 2               Services Australia     2020-04-07 00:00:00
# 3             Department of Health     2019-12-19 00:00:00
# 4  Administrative Appeals Tribunal     2019-07-25 00:00:00
#
#   Applicable Start Date  Applicable End Date Applicable Value  \
# 0            2019-05-01  2019-05-31 00:00:00          16163.4
# 1            2020-05-25  2023-06-30 00:00:00           648000
# 2            2020-03-19  2020-03-27 00:00:00           155998
# 3            2020-01-02  2020-06-30 00:00:00           169542
# 4            2019-06-01  2019-07-31 00:00:00          13263.5
#
#    Applicable FY Year Duration Years   Amendment Reason  \
# 0                2020       0.222222  No Amendment done
# 1                2020        3.09722          Variation
# 2                2020      0.0277778  No Amendment done
# 3                2020       0.530556  No Amendment done
# 4                2020      0.0166667     Extension date
#
#               Description                      UNSPSC Title  ...  \
# 0       Fitness Equipment                 Fitness equipment  ...
# 1    Software Maintenance  Software maintenance and support  ...
# 2       Training Services   Education and Training Services  ...
# 3             Labour Hire             Personnel recruitment  ...
# 4  Labour hire contractor      Temporary personnel services  ...
#
#                      Supplier Name               Supplier Address  \
# 0  BLP TRAINING & SERVICES PTY LTD                            NaN
# 1            IBM Australia Limited                            NaN
# 2           Benestar Group Pty Ltd                   PO Box Q1436
# 3         PEOPLEBANK AUSTRALIA LTD                            NaN
# 4       LAUNCH RECRUITMENT PTY LTD  LEVEL 10 1 CASTLEREAGH STREET
#
#           Supplier Suburb Supplier Postcode Supplier State Supplier Country  \
# 0               BEENLEIGH              4207            QLD        AUSTRALIA
# 1           Pennant Hills              1715            NSW        AUSTRALIA
# 2  QVB Post Office Sydney              1230            NSW        AUSTRALIA
# 3            NORTH SYDNEY              2060            NSW        AUSTRALIA
# 4                  SYDNEY              2000            NSW        AUSTRALIA
#
#   Supplier ABN Exempt                                             Branch  \
# 0                  No                                Army Forces Command
# 1                  No                                                NaN
# 2                  No                                         DHS Branch
# 3                  No                                                NaN
# 4                  No  Administrative Appeals Tribunal Administrative...
#
#                                  Division Office Postcode
# 0                       ARMY HEADQUARTERS            2021
# 1                                     NaN            2617
# 2                            DHS Division            2900
# 3  Cancer Hearing and Program Support DIV            2606
# 4     AAT Administrative Appeals Tribunal            4000
#
# [5 rows x 28 columns]

# %%
clean_df.isnull().sum()
# Out:
# Agency Name                             0
# Applicable Publish Date                 0
# Applicable Start Date                 114
# Applicable End Date                     0
# Applicable Value                        0
# Applicable FY Year                      0
# Duration Years                        117
# Amendment Reason                        0
# Description                             3
# UNSPSC Title                            0
# Procurement Method                      0
# Panel Arrangement                  234842
# Confidentiality Contract Flag        3275
# Confidentiality Contract Reason    359126
# Confidentiality Outputs Flag         3275
# Confidentiality Outputs Reason     359428
# Consultancy Flag                     3275
# Consultancy Reason                 349081
# Supplier Name                           0
# Supplier Address                   135744
# Supplier Suburb                       315
# Supplier Postcode                    1783
# Supplier State                          0
# Supplier Country                        0
# Supplier ABN Exempt                     0
# Branch                             111808
# Division                            57155
# Office Postcode                         0
# dtype: int64

# %%
clean_df.dtypes
# Out:
# Agency Name                                object
# Applicable Publish Date                    object
# Applicable Start Date              datetime64[ns]
# Applicable End Date                        object
# Applicable Value                           object
# Applicable FY Year                          int64
# Duration Years                             object
# Amendment Reason                           object
# Description                                object
# UNSPSC Title                               object
# Procurement Method                         object
# Panel Arrangement                          object
# Confidentiality Contract Flag              object
# Confidentiality Contract Reason            object
# Confidentiality Outputs Flag               object
# Confidentiality Outputs Reason             object
# Consultancy Flag                           object
# Consultancy Reason                         object
# Supplier Name                              object
# Supplier Address                           object
# Supplier Suburb                            object
# Supplier Postcode                          object
# Supplier State                             object
# Supplier Country                           object
# Supplier ABN Exempt                        object
# Branch                                     object
# Division                                   object
# Office Postcode                            object
# dtype: object

# %%
clean_df.head(20)
# Out:
#                         Agency Name Applicable Publish Date  \
# 0             Department of Defence     2019-08-20 00:00:00
# 1   Australian Bureau of Statistics     2020-05-25 00:00:00
# 2                Services Australia     2020-04-07 00:00:00
# 3              Department of Health     2019-12-19 00:00:00
# 4   Administrative Appeals Tribunal     2019-07-25 00:00:00
# 5   Administrative Appeals Tribunal     2019-07-01 00:00:00
# 6   Administrative Appeals Tribunal     2020-02-24 00:00:00
# 7   Administrative Appeals Tribunal     2020-03-31 00:00:00
# 8   Administrative Appeals Tribunal     2020-01-23 00:00:00
# 9   Administrative Appeals Tribunal     2020-06-11 00:00:00
# 10  Administrative Appeals Tribunal     2020-01-15 00:00:00
# 11  Administrative Appeals Tribunal     2019-07-31 00:00:00
# 12  Administrative Appeals Tribunal     2020-06-11 00:00:00
# 13  Administrative Appeals Tribunal     2019-07-01 00:00:00
# 14  Administrative Appeals Tribunal     2020-03-31 00:00:00
# 15  Administrative Appeals Tribunal     2020-03-31 00:00:00
# 16  Administrative Appeals Tribunal     2020-01-15 00:00:00
# 17  Administrative Appeals Tribunal     2019-11-04 00:00:00
# 18  Administrative Appeals Tribunal     2020-02-24 00:00:00
# 19  Administrative Appeals Tribunal     2020-01-16 00:00:00
#
#    Applicable Start Date  Applicable End Date Applicable Value  \
# 0             2019-05-01  2019-05-31 00:00:00          16163.4
# 1             2020-05-25  2023-06-30 00:00:00           648000
# 2             2020-03-19  2020-03-27 00:00:00           155998
# 3             2020-01-02  2020-06-30 00:00:00           169542
# 4             2019-06-01  2019-07-31 00:00:00          13263.5
# 5             2019-06-28  2020-06-30 00:00:00          78944.8
# 6             2020-02-11  2021-12-31 00:00:00          54214.1
# 7             2020-03-19  2021-03-18 00:00:00          52546.7
# 8             2019-07-01  2020-06-30 00:00:00            44075
# 9             2020-05-26  2023-06-27 00:00:00           158927
# 10            2019-07-01  2020-06-30 00:00:00           149749
# 11            2018-07-01  2019-06-30 00:00:00          83685.9
# 12            2020-03-19  2022-01-31 00:00:00           296988
# 13            2019-06-25  2022-06-25 00:00:00          31386.9
# 14            2020-03-25  2020-09-24 00:00:00          18968.4
# 15            2020-02-19  2020-06-30 00:00:00          51489.2
# 16            2019-07-01  2019-11-30 00:00:00      1.58505e+06
# 17            2019-09-24  2020-03-27 00:00:00            11616
# 18            2020-02-14  2020-02-17 00:00:00          13698.6
# 19            2019-07-01  2020-06-30 00:00:00          38165.8
#
#     Applicable FY Year Duration Years                 Amendment Reason  \
# 0                 2020       0.222222                No Amendment done
# 1                 2020        3.09722                        Variation
# 2                 2020      0.0277778                No Amendment done
# 3                 2020       0.530556                No Amendment done
# 4                 2020      0.0166667                   Extension date
# 5                 2020       0.997222                No Amendment done
# 6                 2020        1.85278                No Amendment done
# 7                 2020       0.966667                No Amendment done
# 8                 2020       0.436111                No Amendment done
# 9                 2020        3.04444                No Amendment done
# 10                2020       0.458333  Amend the price with new period
# 11                2020      0.0833333            Based on actual costs
# 12                2020        1.63889                No Amendment done
# 13                2020        2.98333                No Amendment done
# 14                2020       0.483333                No Amendment done
# 15                2020           0.25                No Amendment done
# 16                2020          0.125            Reflect to new period
# 17                2020       0.397222                No Amendment done
# 18                2020      0.0194444                No Amendment done
# 19                2020       0.455556  Amend the price with new period
#
#                                           Description  \
# 0                                   Fitness Equipment
# 1                                Software Maintenance
# 2                                   Training Services
# 3                                         Labour Hire
# 4                              Labour hire contractor
# 5        Avoka software Licensing ans Support renewal
# 6   Liberty Recording software maintenance 134 Rec...
# 7                                      Cisco Licences
# 8                              Labour Hire Contractor
# 9   7 x Surface Hubs 7 x Surface Studios plus freight
# 10                Providing interpreting services\r\n
# 11                     Early Case Assessment Panelist
# 12           Secure Internet Gateway 3 year extension
# 13                     3 Year Support and Maintenance
# 14                                         Blackberry
# 15                       Labour Hire- Alexis Zapantis
# 16  Security Services (estimated contract value to...
# 17                      Project Manager - Labour Hire
# 18                      Mobile Handset  & Phone Costs
# 19                         Property Lease preparation
#
#                                          UNSPSC Title  ...  \
# 0                                   Fitness equipment  ...
# 1                    Software maintenance and support  ...
# 2                     Education and Training Services  ...
# 3                               Personnel recruitment  ...
# 4                        Temporary personnel services  ...
# 5                                            Software  ...
# 6                                            Software  ...
# 7                                            Software  ...
# 8                        Temporary personnel services  ...
# 9   Audio and visual presentation and composing eq...  ...
# 10                                       Interpreters  ...
# 11                       Temporary personnel services  ...
# 12                                  Internet services  ...
# 13                                           Software  ...
# 14                                           Software  ...
# 15                       Temporary personnel services  ...
# 16                            Security guard services  ...
# 17                       Temporary personnel services  ...
# 18                                      Mobile phones  ...
# 19           Lease and rental of property or building  ...
#
#                          Supplier Name                  Supplier Address  \
# 0      BLP TRAINING & SERVICES PTY LTD                               NaN
# 1                IBM Australia Limited                               NaN
# 2               Benestar Group Pty Ltd                      PO Box Q1436
# 3             PEOPLEBANK AUSTRALIA LTD                               NaN
# 4           LAUNCH RECRUITMENT PTY LTD     LEVEL 10 1 CASTLEREAGH STREET
# 5                       AXIENT PTY LTD                        PO BOX 119
# 6               EPIQ AUSTRALIA PTY LTD         190 LEVEL 4, QUEEN STREET
# 7        DATACOM SYSTEMS (NSW) PTY LTD                       PO BOX 2076
# 8     AUSTRALIAN MEDIATION ASSOCIATION                               NaN
# 9                      DATA #3 LIMITED                        PO BOX 551
# 10            Language Experts Pty Ltd                       P.O.BOX 142
# 11                        Susan Waring                               NaN
# 12                   MACQUARIE TELECOM                   2 MARKET STREET
# 13    CONVERGED COMMUNICATIONS NETWORK               3 WARRINGTON AVENUE
# 14          ISEC7 ASIA PACIFIC PTY LTD   Lv17/16-40 THE ARK MOUNT STREET
# 15  HAYS PERSONNEL SERVICES (AUST) P/L                      GPO BOX 3868
# 16             Wilson Security Pty Ltd         L16, 360 ELIZABETH STREET
# 17                   GREYTHORN PTY LTD  LEVEL 22, TOWER 2, 210 SUSSEX ST
# 18                             TELSTRA                      GPO BOX 9901
# 19                    MADDOCKS LAWYERS            LAWYERS 140 WILLIAM ST
#
#            Supplier Suburb Supplier Postcode Supplier State Supplier Country  \
# 0                BEENLEIGH              4207            QLD        AUSTRALIA
# 1            Pennant Hills              1715            NSW        AUSTRALIA
# 2   QVB Post Office Sydney              1230            NSW        AUSTRALIA
# 3             NORTH SYDNEY              2060            NSW        AUSTRALIA
# 4                   SYDNEY              2000            NSW        AUSTRALIA
# 5               CROWS NEST              2065            NSW        AUSTRALIA
# 6                MELBOURNE              3000            VIC        AUSTRALIA
# 7               NORTH RYDE              1670            NSW        AUSTRALIA
# 8                 BRISBANE              4001            QLD        AUSTRALIA
# 9            INDOOROOPILLY              4068            QLD        AUSTRALIA
# 10            Surrey Hills              3127            VIC        AUSTRALIA
# 11                Brisbane              4000            QLD        AUSTRALIA
# 12                  SYDNEY              2000            NSW        AUSTRALIA
# 13               CARINGBAH              2229            NSW        AUSTRALIA
# 14            NORTH SYDNEY              2060            NSW        AUSTRALIA
# 15                  SYDNEY              2001            NSW        AUSTRALIA
# 16               Melbourne              3000            VIC        AUSTRALIA
# 17                  SYDNEY              2000            NSW        AUSTRALIA
# 18               MELBOURNE              3001            VIC        AUSTRALIA
# 19               Melbourne              3000            VIC        AUSTRALIA
#
#    Supplier ABN Exempt                                             Branch  \
# 0                   No                                Army Forces Command
# 1                   No                                                NaN
# 2                   No                                         DHS Branch
# 3                   No                                                NaN
# 4                   No  Administrative Appeals Tribunal Administrative...
# 5                   No  Administrative Appeals Tribunal Administrative...
# 6                   No  Administrative Appeals Tribunal Administrative...
# 7                   No  Administrative Appeals Tribunal Administrative...
# 8                   No                                                NaN
# 9                   No  Administrative Appeals Tribunal Administrative...
# 10                  No                                                NaN
# 11                  No                                                NaN
# 12                  No  Administrative Appeals Tribunal Administrative...
# 13                  No  Administrative Appeals Tribunal Administrative...
# 14                  No  Administrative Appeals Tribunal Administrative...
# 15                  No  Administrative Appeals Tribunal Administrative...
# 16                  No                                                NaN
# 17                  No  Administrative Appeals Tribunal Administrative...
# 18                  No  Administrative Appeals Tribunal Administrative...
# 19                  No                                                NaN
#
#                                   Division Office Postcode
# 0                        ARMY HEADQUARTERS            2021
# 1                                      NaN            2617
# 2                             DHS Division            2900
# 3   Cancer Hearing and Program Support DIV            2606
# 4      AAT Administrative Appeals Tribunal            4000
# 5      AAT Administrative Appeals Tribunal            4000
# 6      AAT Administrative Appeals Tribunal            4000
# 7      AAT Administrative Appeals Tribunal            4000
# 8                                      NaN            3000
# 9      AAT Administrative Appeals Tribunal            4000
# 10                                     NaN            3000
# 11                                     NaN            3000
# 12     AAT Administrative Appeals Tribunal            4000
# 13     AAT Administrative Appeals Tribunal            4000
# 14     AAT Administrative Appeals Tribunal            4000
# 15     AAT Administrative Appeals Tribunal            4000
# 16                                     NaN            3000
# 17     AAT Administrative Appeals Tribunal            4000
# 18     AAT Administrative Appeals Tribunal            4000
# 19                                     NaN            3000
#
# [20 rows x 28 columns]

# %% [markdown]
# Data types for each feature looks fine.

# %%
# Creating CSV file with the clean data
clean_df.to_csv('tender_full.csv',sep= '|' , index=False)
df_supplier_details.to_csv('supplier.csv', encoding='utf-8', index=False)
